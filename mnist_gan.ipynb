# %% [markdown]
# <a href="https://colab.research.google.com/github/abhibeats95/Mnist-GAN/blob/main/mnist_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os 
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
def sigmoid(input,derivative=False):
  res=1/(1+np.exp(-input))
  if derivative:
    return res*(1-res)
  return res

def relu(input, derivative=False):
  res= input
  if derivative:
    return 1.0*(res>0)
  else:
    return res * (res>0)

def lrelu(input,alpha=0.01,derivative=False):
  res=input
  if derivative:
    dx=np.ones_like(res)
    dx[res<0]=alpha
    return dx
  else :
    return np.maximum(input,input*alpha,input)
  
def tanh(input, derivative=False):
	res = np.tanh(input)
	if derivative:
		return 1.0 - np.tanh(input) ** 2
	return res

# %%
def mnist_reader(numbers):
  def one_hot(label,output_dim):
    one_hot=np.zeros((len(labels),output_dim))

    for idx in range(0,len(label)):
      one_hot[idx,label[idx]]=1

      return one_hot

   ##training_Data
  f = open('/content/drive/MyDrive/Colab Notebooks/mnist_gan/train-images.idx3-ubyte')
  loaded=np.fromfile(file=f,dtype=np.uint8)
  trainX = loaded[16:].reshape((60000, 28, 28, 1)).astype(np.float32) 

  f = open('/content/drive/MyDrive/Colab Notebooks/mnist_gan/train-labels.idx1-ubyte')
  loaded = np.fromfile(file=f, dtype=np.uint8)
  trainY = loaded[8:].reshape((60000)).astype(np.int32)

  newtrainX=[]

  for idx in range(0,len(trainX)):
    if trainY[idx] in numbers:
      newtrainX.append(trainX[idx])
        
  return np.array(newtrainX), trainY,len(trainX)

def img_tile(imgs, path, epoch, step, name, save, aspect_ratio=1.0, tile_shape=None, border=1, border_color=0):
	if imgs.ndim != 3 and imgs.ndim != 4:
		raise ValueError('imgs has wrong number of dimensions.')
	n_imgs = imgs.shape[0]

	tile_shape = None
	# Grid shape
	img_shape = np.array(imgs.shape[1:3])
	if tile_shape is None:
		img_aspect_ratio = img_shape[1] / float(img_shape[0])
		aspect_ratio *= img_aspect_ratio
		tile_height = int(np.ceil(np.sqrt(n_imgs * aspect_ratio)))
		tile_width = int(np.ceil(np.sqrt(n_imgs / aspect_ratio)))
		grid_shape = np.array((tile_height, tile_width))
	else:
		assert len(tile_shape) == 2
		grid_shape = np.array(tile_shape)

	# Tile image shape
	tile_img_shape = np.array(imgs.shape[1:])
	tile_img_shape[:2] = (img_shape[:2] + border) * grid_shape[:2] - border

	# Assemble tile image
	tile_img = np.empty(tile_img_shape)
	tile_img[:] = border_color
	for i in range(grid_shape[0]):
		for j in range(grid_shape[1]):
			img_idx = j + i*grid_shape[1]
			if img_idx >= n_imgs:
				# No more images - stop filling out the grid.
				break

			#-1~1 to 0~1
			img = (imgs[img_idx] + 1)/2.0# * 255.0

			yoff = (img_shape[0] + border) * i
			xoff = (img_shape[1] + border) * j
			tile_img[yoff:yoff+img_shape[0], xoff:xoff+img_shape[1], ...] = img 


	path_name = path + "/epoch_%03d"%(epoch)+".jpg"

	##########################################
	# Change code below if you want to save results using PIL
	##########################################
	tile_img = cv2.resize(tile_img, (256,256))
	cv2_imshow(name, tile_img)
	cv2.waitKey(1)
	if save:	
		cv2.imwrite(path_name, tile_img*255)

# %%
epsilon =10e-8
class GAN(object):
  def __init__(self,numbers):
    self.numbers=numbers
    self.epochs=100
    self.batch_size=64
    self.learning_rate=0.001
    self.decay=0.001

    self.img_path="./images"

    if not os.path.exists(self.img_path):
      os.makedirs(self.img_path)
    

    ###generator_weights
    self.g_W0=np.random.randn(100,128).astype(np.float32)*np.sqrt(2.0/(100))
    self.g_b0=np.zeros(128).astype(np.float32)

    self.g_W1=np.random.randn(128,784).astype(np.float32)*np.sqrt(2.0/(128))
    self.g_b1=np.zeros(784).astype(np.float32)

    ##discriminator weights
    self.d_W0=np.random.randn(784,128).astype(np.float32)*np.sqrt(2.0/(784))
    self.d_b0=np.zeros(128).astype(np.float32)

    self.d_W1=np.random.randn(128,1).astype(np.float32)*np.sqrt(2.0/(128))
    self.d_b1=np.zeros(1).astype(np.float32)
  
  
  def discriminator(self,img):
    self.d_input=np.reshape(img,(self.batch_size,-1))

    self.d_h0_l=self.d_input.dot(self.d_W0)+self.d_b0
    self.d_h0_a=lrelu(self.d_h0_l)


    self.d_h1_l=self.d_h0_a.dot(self.d_W1)+ self.d_b1
    self.d_h1_a= sigmoid(self.d_h1_l)

    self.d_out=self.d_h1_a

    return self.d_h1_l,self.d_out

  def generator(self,z):

    self.z= np.reshape(z,(self.batch_size,-1))

    self.g_h0_l=self.z.dot(self.g_W0)+self.g_b0
    self.g_h0_a=lrelu(self.g_h0_l)

    self.g_h1_l=self.g_h0_a.dot(self.g_W1)+self.g_b1
    self.g_h1_a=tanh(self.g_h1_l)

    self.g_out= np.reshape(self.g_h1_a,(self.batch_size,28,28))


    return self.g_h1_l,self.g_out


  ##Generator backpropogation

  def backprop_gen(self,
                   
                   fake_logit,
                   fake_output,
                   fake_input):
    

    fake_input=np.reshape(fake_input,(self.batch_size,-1))

    ##calculate the derivative of loss term

    g_loss=np.reshape(fake_output,(self.batch_size,-1))
    g_loss=-1.0/(g_loss+epsilon)



    loss_deriv=g_loss*sigmoid(fake_logit,derivative=True)
    loss_deriv=loss_deriv.dot(self.d_W1.T)

    loss_deriv=loss_deriv*lrelu(self.d_h0_l,derivative=True)
    loss_deriv=loss_deriv.dot(self.d_W0.T)
    ##reached at the end of  generator

    ##Calculate generator_gradients
    loss_deriv=loss_deriv*tanh(self.g_h1_l,derivative=True)
    prev_layer=np.expand_dims(self.g_h0_a,axis=-1)
    loss_deriv_=np.expand_dims(loss_deriv,axis=1)
    grad_W1=np.matmul(prev_layer,loss_deriv_)
    grad_b1=loss_deriv

    loss_deriv=loss_deriv.dot(self.g_W1.T)

    loss_deriv=loss_deriv*lrelu(self.g_h0_l,derivative=True)
    prev_layer=np.expand_dims(self.z,axis=-1)
    loss_deriv_=np.expand_dims(loss_deriv,axis=1)
    grad_W0=np.matmul(prev_layer,loss_deriv_)
    grad_b0=loss_deriv


    for idx in range(self.batch_size):
      self.g_W0=self.g_W0  -   self.learning_rate*grad_W0[idx]
      self.g_b0=self.g_b0  -   self.learning_rate*grad_b0[idx]

      self.g_W1=self.g_W1  -   self.learning_rate*grad_W1[idx]
      self.g_b1=self.g_b1  -   self.learning_rate*grad_b1[idx]

  def backprop_dis(self,
                   real_logit,real_output,real_input,
                   fake_logit,fake_output,fake_input):
    
    real_input=np.reshape(real_input,(self.batch_size,-1))
    fake_input=np.reshape(fake_input,(self.batch_size,-1))

    
		# Discriminator loss = -np.mean(log(D(x)) + log(1-D(G(z))))
    
    d_real_loss=-1.0/(real_output+epsilon)
    d_fake_loss=-1.0/(fake_output+epsilon)


    # start from the error in the last layer

    loss_deriv=d_real_loss*sigmoid(real_logit,derivative=True)
    prev_layer=np.expand_dims(self.d_h0_a,axis=-1)
    loss_deriv_=np.expand_dims(loss_deriv,axis=1)
    grad_real_W1=np.matmul(prev_layer,loss_deriv_)
    grad_real_b1=loss_deriv


    loss_deriv=loss_deriv.dot(self.d_W1.T)

    loss_deriv= loss_deriv*lrelu(self.d_h0_l,derivative=True)
    prev_layer= np.expand_dims(real_input,axis=-1)
    loss_deriv_=np.expand_dims(loss_deriv,axis=1)
    grad_real_W0  =np.matmul(prev_layer,loss_deriv_)
    grad_real_b0=loss_deriv


    ###fake imahes gradients

    loss_deriv = d_fake_loss*sigmoid(fake_logit,derivative=True)
    prev_layer = np.expand_dims(self.d_h0_a,axis=-1)
    loss_deriv_=np.expand_dims(loss_deriv,axis=1)
    grad_fake_W1=np.matmul(prev_layer,loss_deriv_)
    grad_fake_b1=loss_deriv

    loss_deriv=loss_deriv.dot(self.d_W1.T)
    loss_deriv=loss_deriv*lrelu(self.d_h0_l,derivative=True)
    prev_layer= np.expand_dims(fake_input,axis=-1)
    loss_deriv_=np.expand_dims(loss_deriv,axis=1)
    grad_fake_W0=np.matmul(prev_layer,loss_deriv_)
    grad_fake_b0=loss_deriv

    #combining all the gradients in the batch

    grad_W1=grad_real_W1+grad_fake_W1
    grad_b1=grad_real_b1+grad_fake_b1

    grad_W0=grad_real_W0+grad_fake_W0
    grad_b0=grad_real_b0+grad_fake_b0


    for idx in range(self.batch_size):
      self.d_W0=self.d_W0-self.learning_rate*grad_W0[idx]
      self.d_b0=self.d_b0-self.learning_rate*grad_b0[idx]

      self.d_W1=self.d_W1-self.learning_rate*grad_W1[idx]
      self.d_b1=self.d_b1-self.learning_rate*grad_b1[idx]


  def train(self):

    trainX,_,train_size=mnist_reader(self.numbers)
    np.random.shuffle(trainX)


    batch_idx=train_size//self.batch_size

    for epoch in range(self.epochs):
      for idx in range(batch_idx):
        train_batch=trainX[idx*self.batch_size:idx*self.batch_size + self.batch_size]
        if train_batch.shape[0]!=self.batch_size:
          break

        z=np.random.uniform(-1,1,[self.batch_size,100])


        ###Forward_pass

        g_logits,fake_img=self.generator(z)

        d_real_logits,d_real_output=self.discriminator(train_batch)
        d_fake_logits,d_fake_output=self.discriminator(fake_img)

        ##cross_entropy lossusing sigmoid
        d_loss=-np.log(d_real_output+epsilon)-np.log(1-d_fake_output+epsilon)

        g_loss=-np.log(d_fake_output+epsilon)


        ################################
				#		Backward Pass
				################################

        # for every result in the batch
				# calculate gradient and update the weights using Adam

				# discriminator backward pass
				# one for fake input, another for real input

        self.backprop_dis(d_real_logits,d_real_output,train_batch,d_fake_logits,d_fake_output,fake_img)

        # generator backward pass
        self.backprop_gen(d_fake_logits, d_fake_output, fake_img)
				# train generator twice?


				#g_logits, fake_img = self.generator(z)
				#d_fake_logits, d_fake_output = self.discriminator(fake_img)
				#self.backprop_gen(d_fake_logits, d_fake_output, fake_img)

				#show res images as tile
				#if you don't want to see the result at every step, comment line below
        #img_tile(np.array(fake_img), self.img_path, epoch, idx, "res", False)
        self.img = fake_img


        print("Epoch [%d] Step [%d] G Loss:%.4f D Loss:%.4f Real Ave.: %.4f Fake Ave.: %.4f lr: %.4f"%(epoch, idx, np.mean(g_loss), np.mean(d_loss), np.mean(d_real_output), np.mean(d_fake_output), self.learning_rate))

			#update learning rate every epoch
      self.learning_rate = self.learning_rate * (1.0/(1.0 + self.decay*epoch))

			#save image result every epoch
      #img_tile(np.array(self.img), self.img_path, epoch, idx, "res", True)




########################
#program starts here
#select numbers to generate
#recommended to put a single number to get faster result
numbers = [2]

gan = GAN(numbers)
gan.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# Streaming output truncated to the last 5000 lines.
# Epoch [46] Step [22] G Loss:0.0000 D Loss:15.2029 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [23] G Loss:0.0000 D Loss:15.4799 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [24] G Loss:0.0000 D Loss:15.2210 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [25] G Loss:0.0000 D Loss:15.2529 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [26] G Loss:0.0000 D Loss:15.3828 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [27] G Loss:0.0000 D Loss:15.2115 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [28] G Loss:0.0000 D Loss:15.3561 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [29] G Loss:0.0000 D Loss:15.1715 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [30] G Loss:0.0000 D Loss:15.4745 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [31] G Loss:0.0000 D Loss:15.6177 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [32] G Loss:0.0000 D Loss:15.4758 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [33] G Loss:0.0000 D Loss:15.3651 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [34] G Loss:0.0000 D Loss:15.3714 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [35] G Loss:0.0000 D Loss:15.4185 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [36] G Loss:0.0000 D Loss:15.4845 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [37] G Loss:0.0000 D Loss:15.1819 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [38] G Loss:0.0000 D Loss:15.5195 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [39] G Loss:0.0000 D Loss:15.5954 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [40] G Loss:0.0000 D Loss:15.4017 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [41] G Loss:0.0000 D Loss:15.5970 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [42] G Loss:0.0000 D Loss:15.4205 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [43] G Loss:0.0000 D Loss:15.5939 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [44] G Loss:0.0000 D Loss:15.1425 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [45] G Loss:0.0000 D Loss:15.3334 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [46] G Loss:0.0000 D Loss:15.3232 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [47] G Loss:0.0000 D Loss:15.5030 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [48] G Loss:0.0000 D Loss:15.5936 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [49] G Loss:0.0000 D Loss:15.2236 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [50] G Loss:0.0000 D Loss:15.5677 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [51] G Loss:0.0000 D Loss:15.5413 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [52] G Loss:0.0000 D Loss:15.5732 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [53] G Loss:0.0000 D Loss:15.3084 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [54] G Loss:0.0000 D Loss:15.0965 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [55] G Loss:0.0000 D Loss:15.3716 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [56] G Loss:0.0000 D Loss:15.2856 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [57] G Loss:0.0000 D Loss:15.3383 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [58] G Loss:0.0000 D Loss:15.4690 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [59] G Loss:0.0000 D Loss:15.3208 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [60] G Loss:0.0000 D Loss:15.3839 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [61] G Loss:0.0000 D Loss:15.4017 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [62] G Loss:0.0000 D Loss:15.4783 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [63] G Loss:0.0000 D Loss:15.4151 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [64] G Loss:0.0000 D Loss:15.2642 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [65] G Loss:0.0000 D Loss:15.2202 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [66] G Loss:0.0000 D Loss:15.4081 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [67] G Loss:0.0000 D Loss:15.5779 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [68] G Loss:0.0000 D Loss:15.3457 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [69] G Loss:0.0000 D Loss:15.7196 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [70] G Loss:0.0000 D Loss:15.6090 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [71] G Loss:0.0000 D Loss:15.2304 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [72] G Loss:0.0000 D Loss:15.3298 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [73] G Loss:0.0000 D Loss:15.4255 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [74] G Loss:0.0000 D Loss:15.4785 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [75] G Loss:0.0000 D Loss:15.1785 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [76] G Loss:0.0000 D Loss:15.2751 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [77] G Loss:0.0000 D Loss:15.3381 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [78] G Loss:0.0000 D Loss:15.4646 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [79] G Loss:0.0000 D Loss:15.5146 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [80] G Loss:0.0000 D Loss:15.3555 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [81] G Loss:0.0000 D Loss:15.4250 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [82] G Loss:0.0000 D Loss:15.3807 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [83] G Loss:0.0000 D Loss:15.0767 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [84] G Loss:0.0000 D Loss:15.3888 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [85] G Loss:0.0000 D Loss:15.3734 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [86] G Loss:0.0000 D Loss:15.4560 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [87] G Loss:0.0000 D Loss:15.1827 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [88] G Loss:0.0000 D Loss:15.0679 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [89] G Loss:0.0000 D Loss:15.3485 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [90] G Loss:0.0000 D Loss:15.6441 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [91] G Loss:0.0000 D Loss:15.2830 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [46] Step [92] G Loss:0.0000 D Loss:15.5948 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0004
# Epoch [47] Step [0] G Loss:0.0000 D Loss:15.2476 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [1] G Loss:0.0000 D Loss:15.1756 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [2] G Loss:0.0000 D Loss:15.4478 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [3] G Loss:0.0000 D Loss:15.5755 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [4] G Loss:0.0000 D Loss:15.3963 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [5] G Loss:0.0000 D Loss:15.6807 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [6] G Loss:0.0000 D Loss:15.5385 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [7] G Loss:0.0000 D Loss:15.1949 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [8] G Loss:0.0000 D Loss:15.4745 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [9] G Loss:0.0000 D Loss:14.9575 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [10] G Loss:0.0000 D Loss:15.2947 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [11] G Loss:0.0000 D Loss:15.5026 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [12] G Loss:0.0000 D Loss:15.3995 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [13] G Loss:0.0000 D Loss:15.4052 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [14] G Loss:0.0000 D Loss:15.2346 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [15] G Loss:0.0000 D Loss:15.4869 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [16] G Loss:0.0000 D Loss:15.3425 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [17] G Loss:0.0000 D Loss:15.3022 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [18] G Loss:0.0000 D Loss:15.6738 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [19] G Loss:0.0000 D Loss:15.1954 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [20] G Loss:0.0000 D Loss:15.0291 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [21] G Loss:0.0000 D Loss:15.3575 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [22] G Loss:0.0000 D Loss:15.4620 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [23] G Loss:0.0000 D Loss:15.4814 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [24] G Loss:0.0000 D Loss:15.4359 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [25] G Loss:0.0000 D Loss:15.7187 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [26] G Loss:0.0000 D Loss:15.5054 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [27] G Loss:0.0000 D Loss:15.6449 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [28] G Loss:0.0000 D Loss:15.2615 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [29] G Loss:0.0000 D Loss:15.1386 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [30] G Loss:0.0000 D Loss:15.5188 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [31] G Loss:0.0000 D Loss:15.1981 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [32] G Loss:0.0000 D Loss:15.4656 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [33] G Loss:0.0000 D Loss:15.4249 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [34] G Loss:0.0000 D Loss:15.2830 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [35] G Loss:0.0000 D Loss:15.1448 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [36] G Loss:0.0000 D Loss:15.3928 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [37] G Loss:0.0000 D Loss:15.4796 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [38] G Loss:0.0000 D Loss:15.4469 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [39] G Loss:0.0000 D Loss:15.5091 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [40] G Loss:0.0000 D Loss:15.2303 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [41] G Loss:0.0000 D Loss:15.2948 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [42] G Loss:0.0000 D Loss:15.5713 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [43] G Loss:0.0000 D Loss:15.0951 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [44] G Loss:0.0000 D Loss:15.3377 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [45] G Loss:0.0000 D Loss:15.4218 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [46] G Loss:0.0000 D Loss:15.1651 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [47] G Loss:0.0000 D Loss:15.5464 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [48] G Loss:0.0000 D Loss:15.4222 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [49] G Loss:0.0000 D Loss:15.4480 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [50] G Loss:0.0000 D Loss:15.4489 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [51] G Loss:0.0000 D Loss:15.2015 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [52] G Loss:0.0000 D Loss:15.5332 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [53] G Loss:0.0000 D Loss:15.4699 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [54] G Loss:0.0000 D Loss:15.2383 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [55] G Loss:0.0000 D Loss:15.5877 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [56] G Loss:0.0000 D Loss:15.1104 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [57] G Loss:0.0000 D Loss:15.5230 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [58] G Loss:0.0000 D Loss:15.1301 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [59] G Loss:0.0000 D Loss:15.4937 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [60] G Loss:0.0000 D Loss:15.1071 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [61] G Loss:0.0001 D Loss:15.2464 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [47] Step [62] G Loss:0.0000 D Loss:15.3323 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [63] G Loss:0.0000 D Loss:15.2671 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [64] G Loss:0.0000 D Loss:15.3630 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [65] G Loss:0.0000 D Loss:15.5675 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [66] G Loss:0.0000 D Loss:15.4435 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [67] G Loss:0.0000 D Loss:15.4631 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [68] G Loss:0.0000 D Loss:15.6737 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [69] G Loss:0.0000 D Loss:15.6080 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [70] G Loss:0.0000 D Loss:15.3393 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [71] G Loss:0.0000 D Loss:15.6283 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [72] G Loss:0.0000 D Loss:15.5898 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [73] G Loss:0.0000 D Loss:15.5212 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [74] G Loss:0.0000 D Loss:15.4870 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [75] G Loss:0.0001 D Loss:15.0983 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [47] Step [76] G Loss:0.0000 D Loss:15.4923 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [77] G Loss:0.0000 D Loss:15.4521 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [78] G Loss:0.0000 D Loss:15.4048 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [79] G Loss:0.0000 D Loss:15.4547 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [80] G Loss:0.0000 D Loss:15.7292 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [81] G Loss:0.0000 D Loss:15.1549 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [82] G Loss:0.0000 D Loss:15.1985 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [83] G Loss:0.0000 D Loss:15.4245 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [84] G Loss:0.0000 D Loss:15.0860 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [85] G Loss:0.0000 D Loss:15.4882 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [86] G Loss:0.0000 D Loss:15.6109 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [87] G Loss:0.0000 D Loss:15.3760 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [88] G Loss:0.0000 D Loss:15.2808 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [89] G Loss:0.0000 D Loss:15.5375 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [90] G Loss:0.0000 D Loss:15.5513 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [91] G Loss:0.0000 D Loss:15.4364 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [47] Step [92] G Loss:0.0000 D Loss:15.1221 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [0] G Loss:0.0000 D Loss:15.4799 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [1] G Loss:0.0001 D Loss:15.0021 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [48] Step [2] G Loss:0.0000 D Loss:15.1526 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [3] G Loss:0.0000 D Loss:15.5729 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [4] G Loss:0.0000 D Loss:15.5813 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [5] G Loss:0.0000 D Loss:15.4941 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [6] G Loss:0.0000 D Loss:15.4820 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [7] G Loss:0.0000 D Loss:15.4532 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [8] G Loss:0.0000 D Loss:15.5166 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [9] G Loss:0.0000 D Loss:15.4738 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [10] G Loss:0.0000 D Loss:15.6198 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [11] G Loss:0.0000 D Loss:15.4200 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [12] G Loss:0.0001 D Loss:15.1472 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [48] Step [13] G Loss:0.0000 D Loss:14.9388 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [14] G Loss:0.0000 D Loss:15.4626 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [15] G Loss:0.0000 D Loss:15.3985 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [16] G Loss:0.0000 D Loss:15.3668 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [17] G Loss:0.0000 D Loss:14.9475 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [18] G Loss:0.0000 D Loss:15.4130 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [19] G Loss:0.0000 D Loss:15.3685 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [20] G Loss:0.0000 D Loss:15.4573 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [21] G Loss:0.0000 D Loss:15.5887 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [22] G Loss:0.0000 D Loss:15.5188 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [23] G Loss:0.0000 D Loss:15.6126 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [24] G Loss:0.0000 D Loss:15.0490 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [25] G Loss:0.0000 D Loss:15.2231 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [26] G Loss:0.0000 D Loss:15.3411 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [27] G Loss:0.0000 D Loss:15.4121 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [28] G Loss:0.0000 D Loss:15.4905 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [29] G Loss:0.0000 D Loss:15.4463 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [30] G Loss:0.0000 D Loss:15.4529 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [31] G Loss:0.0000 D Loss:14.9607 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [32] G Loss:0.0000 D Loss:15.3260 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [33] G Loss:0.0000 D Loss:15.3570 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [34] G Loss:0.0000 D Loss:15.4080 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [35] G Loss:0.0000 D Loss:15.6002 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [36] G Loss:0.0000 D Loss:15.2847 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [37] G Loss:0.0000 D Loss:15.1493 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [38] G Loss:0.0000 D Loss:15.3081 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [39] G Loss:0.0000 D Loss:15.3838 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [40] G Loss:0.0000 D Loss:15.2585 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [41] G Loss:0.0000 D Loss:15.3742 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [42] G Loss:0.0000 D Loss:15.3556 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [43] G Loss:0.0000 D Loss:15.3005 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [44] G Loss:0.0000 D Loss:15.3859 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [45] G Loss:0.0000 D Loss:15.0753 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [46] G Loss:0.0000 D Loss:15.4458 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [47] G Loss:0.0000 D Loss:15.4131 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [48] G Loss:0.0000 D Loss:15.3715 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [49] G Loss:0.0000 D Loss:15.6112 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [50] G Loss:0.0001 D Loss:15.0126 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [48] Step [51] G Loss:0.0000 D Loss:15.2315 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [52] G Loss:0.0000 D Loss:15.2661 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [53] G Loss:0.0000 D Loss:15.5532 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [54] G Loss:0.0000 D Loss:15.4049 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [55] G Loss:0.0000 D Loss:15.3688 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [56] G Loss:0.0000 D Loss:15.5480 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [57] G Loss:0.0000 D Loss:15.2420 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [58] G Loss:0.0000 D Loss:15.0288 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [59] G Loss:0.0000 D Loss:15.2638 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [60] G Loss:0.0000 D Loss:15.3059 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [61] G Loss:0.0000 D Loss:15.4733 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [62] G Loss:0.0000 D Loss:15.1693 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [63] G Loss:0.0000 D Loss:15.4732 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [64] G Loss:0.0000 D Loss:15.6526 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [65] G Loss:0.0000 D Loss:15.4554 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [66] G Loss:0.0000 D Loss:15.3304 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [67] G Loss:0.0000 D Loss:15.2655 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [68] G Loss:0.0000 D Loss:15.5155 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [69] G Loss:0.0000 D Loss:15.3725 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [70] G Loss:0.0000 D Loss:15.4343 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [71] G Loss:0.0000 D Loss:15.0339 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [72] G Loss:0.0000 D Loss:15.5329 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [73] G Loss:0.0000 D Loss:15.2157 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [74] G Loss:0.0000 D Loss:15.3997 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [75] G Loss:0.0000 D Loss:15.4874 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [76] G Loss:0.0000 D Loss:15.3919 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [77] G Loss:0.0005 D Loss:15.0032 Real Ave.: 1.0000 Fake Ave.: 0.9995 lr: 0.0003
# Epoch [48] Step [78] G Loss:0.0000 D Loss:15.5825 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [79] G Loss:0.0000 D Loss:15.5279 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [80] G Loss:0.0000 D Loss:15.2219 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [81] G Loss:0.0000 D Loss:15.5586 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [82] G Loss:0.0000 D Loss:15.3742 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [83] G Loss:0.0000 D Loss:15.1822 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [84] G Loss:0.0000 D Loss:15.1216 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [85] G Loss:0.0000 D Loss:15.4208 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [86] G Loss:0.0000 D Loss:15.4779 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [87] G Loss:0.0002 D Loss:15.2330 Real Ave.: 1.0000 Fake Ave.: 0.9998 lr: 0.0003
# Epoch [48] Step [88] G Loss:0.0000 D Loss:15.1556 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [89] G Loss:0.0000 D Loss:15.5394 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [90] G Loss:0.0000 D Loss:15.2984 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [91] G Loss:0.0000 D Loss:15.3358 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [48] Step [92] G Loss:0.0000 D Loss:15.1918 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [0] G Loss:0.0000 D Loss:15.4524 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [1] G Loss:0.0000 D Loss:15.2273 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [2] G Loss:0.0000 D Loss:15.5172 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [3] G Loss:0.0000 D Loss:15.3012 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [4] G Loss:0.0000 D Loss:15.5554 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [5] G Loss:0.0000 D Loss:15.4543 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [6] G Loss:0.0000 D Loss:15.5025 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [7] G Loss:0.0000 D Loss:15.5399 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [8] G Loss:0.0000 D Loss:15.3118 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [9] G Loss:0.0000 D Loss:15.4495 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [10] G Loss:0.0000 D Loss:15.5053 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [11] G Loss:0.0000 D Loss:15.3860 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [12] G Loss:0.0000 D Loss:15.5621 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [13] G Loss:0.0000 D Loss:15.2724 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [14] G Loss:0.0000 D Loss:15.3215 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [15] G Loss:0.0000 D Loss:15.2277 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [16] G Loss:0.0000 D Loss:15.0050 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [17] G Loss:-0.0000 D Loss:15.7621 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [18] G Loss:0.0000 D Loss:15.5094 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [19] G Loss:0.0000 D Loss:15.2807 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [20] G Loss:0.0000 D Loss:15.1973 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [21] G Loss:0.0000 D Loss:15.1329 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [22] G Loss:0.0000 D Loss:15.5123 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [23] G Loss:0.0000 D Loss:15.4794 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [24] G Loss:0.0000 D Loss:15.2078 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [25] G Loss:0.0000 D Loss:15.2734 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [26] G Loss:0.0000 D Loss:15.3883 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [27] G Loss:0.0000 D Loss:15.5970 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [28] G Loss:0.0000 D Loss:15.0215 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [29] G Loss:0.0000 D Loss:15.3788 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [30] G Loss:0.0000 D Loss:15.5607 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [31] G Loss:0.0000 D Loss:15.3259 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [32] G Loss:0.0000 D Loss:15.6127 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [33] G Loss:0.0000 D Loss:15.3097 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [34] G Loss:0.0000 D Loss:15.5366 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [35] G Loss:0.0000 D Loss:15.5942 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [36] G Loss:0.0000 D Loss:15.4985 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [37] G Loss:0.0000 D Loss:15.2690 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [38] G Loss:0.0000 D Loss:15.5684 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [39] G Loss:0.0000 D Loss:15.5847 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [40] G Loss:0.0000 D Loss:15.0209 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [41] G Loss:0.0000 D Loss:15.3506 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [42] G Loss:0.0000 D Loss:15.4608 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [43] G Loss:0.0000 D Loss:15.4545 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [44] G Loss:0.0000 D Loss:15.5453 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [45] G Loss:0.0000 D Loss:15.5080 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [46] G Loss:0.0000 D Loss:15.1773 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [47] G Loss:0.0000 D Loss:15.3998 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [48] G Loss:0.0000 D Loss:15.3326 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [49] G Loss:0.0000 D Loss:15.4375 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [50] G Loss:0.0000 D Loss:15.4171 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [51] G Loss:0.0000 D Loss:15.5570 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [52] G Loss:0.0000 D Loss:15.4301 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [53] G Loss:0.0000 D Loss:15.0877 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [54] G Loss:0.0000 D Loss:15.3115 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [55] G Loss:0.0000 D Loss:15.3798 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [56] G Loss:0.0000 D Loss:15.1683 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [57] G Loss:0.0000 D Loss:15.5006 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [58] G Loss:0.0000 D Loss:15.4940 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [59] G Loss:0.0000 D Loss:15.3637 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [60] G Loss:0.0000 D Loss:15.3078 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [61] G Loss:0.0000 D Loss:15.6022 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [62] G Loss:0.0000 D Loss:15.5086 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [63] G Loss:0.0000 D Loss:15.2814 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [64] G Loss:0.0000 D Loss:15.0937 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [65] G Loss:0.0000 D Loss:15.5376 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [66] G Loss:0.0001 D Loss:15.1180 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [49] Step [67] G Loss:0.0000 D Loss:15.6728 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [68] G Loss:0.0000 D Loss:15.1321 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [69] G Loss:0.0000 D Loss:14.9946 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [70] G Loss:0.0000 D Loss:15.2665 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [71] G Loss:0.0000 D Loss:15.6557 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [72] G Loss:0.0000 D Loss:15.2584 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [73] G Loss:0.0000 D Loss:15.4702 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [74] G Loss:0.0000 D Loss:15.4998 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [75] G Loss:0.0000 D Loss:15.3233 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [76] G Loss:0.0000 D Loss:15.5457 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [77] G Loss:0.0000 D Loss:15.5207 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [78] G Loss:0.0000 D Loss:15.2130 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [79] G Loss:0.0000 D Loss:15.3580 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [80] G Loss:0.0000 D Loss:15.3303 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [81] G Loss:0.0000 D Loss:15.4133 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [82] G Loss:0.0000 D Loss:15.1005 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [83] G Loss:0.0000 D Loss:15.2061 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [84] G Loss:0.0000 D Loss:15.2874 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [85] G Loss:0.0000 D Loss:15.3902 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [86] G Loss:0.0000 D Loss:15.3680 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [87] G Loss:0.0000 D Loss:15.5968 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [88] G Loss:0.0000 D Loss:15.6088 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [89] G Loss:0.0000 D Loss:15.6342 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [90] G Loss:0.0000 D Loss:15.2341 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [91] G Loss:0.0000 D Loss:15.2460 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [49] Step [92] G Loss:0.0000 D Loss:15.5622 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [0] G Loss:0.0000 D Loss:15.2362 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [1] G Loss:0.0000 D Loss:15.5324 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [2] G Loss:0.0000 D Loss:15.2650 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [3] G Loss:0.0000 D Loss:15.4970 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [4] G Loss:0.0000 D Loss:15.5763 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [5] G Loss:0.0000 D Loss:15.2048 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [6] G Loss:0.0000 D Loss:15.6388 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [7] G Loss:0.0000 D Loss:15.2868 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [8] G Loss:0.0000 D Loss:15.5273 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [9] G Loss:0.0001 D Loss:14.9658 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [50] Step [10] G Loss:0.0000 D Loss:15.3674 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [11] G Loss:0.0000 D Loss:15.3324 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [12] G Loss:0.0000 D Loss:14.9856 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [13] G Loss:0.0000 D Loss:15.4549 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [14] G Loss:0.0000 D Loss:15.1814 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [15] G Loss:0.0000 D Loss:15.6247 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [16] G Loss:0.0000 D Loss:15.4189 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [17] G Loss:0.0000 D Loss:15.6297 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [18] G Loss:0.0000 D Loss:15.2865 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [19] G Loss:0.0000 D Loss:15.2960 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [20] G Loss:0.0000 D Loss:15.0597 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [21] G Loss:0.0000 D Loss:15.2548 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [22] G Loss:0.0000 D Loss:15.5396 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [23] G Loss:0.0000 D Loss:15.1612 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [24] G Loss:0.0000 D Loss:15.3925 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [25] G Loss:0.0000 D Loss:15.2838 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [26] G Loss:0.0000 D Loss:15.2630 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [27] G Loss:0.0000 D Loss:15.3487 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [28] G Loss:0.0000 D Loss:15.4442 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [29] G Loss:0.0000 D Loss:15.4914 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [30] G Loss:0.0000 D Loss:15.1905 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [31] G Loss:0.0000 D Loss:15.2978 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [32] G Loss:0.0000 D Loss:15.5356 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [33] G Loss:0.0000 D Loss:15.4899 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [34] G Loss:0.0000 D Loss:15.4685 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [35] G Loss:0.0000 D Loss:15.1464 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [36] G Loss:0.0000 D Loss:15.4993 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [37] G Loss:0.0000 D Loss:15.5604 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [38] G Loss:0.0000 D Loss:15.2299 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [39] G Loss:0.0000 D Loss:15.4296 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [40] G Loss:0.0000 D Loss:15.2976 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [41] G Loss:0.0000 D Loss:15.5794 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [42] G Loss:0.0000 D Loss:15.7144 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [43] G Loss:0.0000 D Loss:15.3263 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [44] G Loss:0.0000 D Loss:15.6968 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [45] G Loss:0.0000 D Loss:15.4439 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [46] G Loss:0.0000 D Loss:15.2166 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [47] G Loss:0.0000 D Loss:15.3371 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [48] G Loss:0.0000 D Loss:15.5441 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [49] G Loss:0.0000 D Loss:15.7091 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [50] G Loss:0.0000 D Loss:15.5465 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [51] G Loss:0.0000 D Loss:15.4207 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [52] G Loss:0.0000 D Loss:15.1858 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [53] G Loss:0.0000 D Loss:15.4620 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [54] G Loss:0.0000 D Loss:15.4251 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [55] G Loss:0.0000 D Loss:15.1812 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [56] G Loss:0.0000 D Loss:15.2022 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [57] G Loss:0.0000 D Loss:15.3104 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [58] G Loss:0.0000 D Loss:15.7324 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [59] G Loss:0.0000 D Loss:15.3580 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [60] G Loss:0.0000 D Loss:15.2189 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [61] G Loss:0.0000 D Loss:15.4932 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [62] G Loss:0.0000 D Loss:15.4196 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [63] G Loss:0.0000 D Loss:15.3634 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [64] G Loss:0.0000 D Loss:15.3153 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [65] G Loss:0.0000 D Loss:15.4082 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [66] G Loss:0.0000 D Loss:15.4778 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [67] G Loss:0.0000 D Loss:15.3483 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [68] G Loss:0.0000 D Loss:15.4553 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [69] G Loss:0.0000 D Loss:15.4284 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [70] G Loss:0.0000 D Loss:15.3026 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [71] G Loss:0.0000 D Loss:15.3627 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [72] G Loss:0.0000 D Loss:15.3686 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [73] G Loss:0.0000 D Loss:15.2120 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [74] G Loss:0.0000 D Loss:15.1695 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [75] G Loss:0.0000 D Loss:15.1096 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [76] G Loss:0.0000 D Loss:15.5428 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [77] G Loss:0.0000 D Loss:15.3966 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [78] G Loss:0.0000 D Loss:15.5073 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [79] G Loss:0.0000 D Loss:15.5328 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [80] G Loss:0.0000 D Loss:15.4427 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [81] G Loss:0.0000 D Loss:15.5243 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [82] G Loss:0.0000 D Loss:15.2771 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [83] G Loss:0.0000 D Loss:15.4003 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [84] G Loss:0.0000 D Loss:15.2362 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [85] G Loss:0.0000 D Loss:15.3117 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [86] G Loss:0.0001 D Loss:15.4283 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [50] Step [87] G Loss:0.0000 D Loss:15.3336 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [88] G Loss:0.0000 D Loss:15.5502 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [89] G Loss:0.0000 D Loss:15.7682 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [90] G Loss:0.0000 D Loss:15.3991 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [91] G Loss:0.0000 D Loss:15.3144 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [50] Step [92] G Loss:0.0000 D Loss:15.1122 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [0] G Loss:0.0000 D Loss:15.5806 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [1] G Loss:0.0000 D Loss:15.5194 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [2] G Loss:0.0000 D Loss:15.3893 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [3] G Loss:0.0000 D Loss:15.4909 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [4] G Loss:0.0000 D Loss:15.4411 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [5] G Loss:0.0000 D Loss:15.1534 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [6] G Loss:0.0000 D Loss:15.3089 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [7] G Loss:0.0000 D Loss:15.3050 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [8] G Loss:0.0000 D Loss:15.5547 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [9] G Loss:0.0000 D Loss:15.0923 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [10] G Loss:0.0000 D Loss:15.4155 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [11] G Loss:0.0000 D Loss:15.3511 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [12] G Loss:0.0000 D Loss:15.3064 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [13] G Loss:0.0000 D Loss:15.6310 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [14] G Loss:0.0000 D Loss:15.3021 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [15] G Loss:0.0000 D Loss:15.4604 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [16] G Loss:0.0000 D Loss:15.1055 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [17] G Loss:0.0000 D Loss:15.5510 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [18] G Loss:0.0000 D Loss:15.3788 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [19] G Loss:0.0000 D Loss:15.5315 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [20] G Loss:0.0000 D Loss:15.0354 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [21] G Loss:0.0000 D Loss:15.4158 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [22] G Loss:0.0000 D Loss:15.4896 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [23] G Loss:0.0000 D Loss:15.5107 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [24] G Loss:0.0000 D Loss:15.6967 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [25] G Loss:0.0000 D Loss:15.6625 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [26] G Loss:0.0000 D Loss:15.2230 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [27] G Loss:0.0000 D Loss:15.1368 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [28] G Loss:0.0000 D Loss:15.3801 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [29] G Loss:0.0000 D Loss:15.4439 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [30] G Loss:0.0000 D Loss:15.4866 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [31] G Loss:0.0000 D Loss:15.5183 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [32] G Loss:0.0000 D Loss:15.3119 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [33] G Loss:0.0000 D Loss:15.3979 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [34] G Loss:0.0001 D Loss:15.2104 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0003
# Epoch [51] Step [35] G Loss:0.0000 D Loss:15.5183 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [36] G Loss:0.0000 D Loss:15.2276 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [37] G Loss:0.0000 D Loss:15.4678 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [38] G Loss:0.0000 D Loss:15.2431 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [39] G Loss:0.0000 D Loss:14.9468 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [40] G Loss:0.0000 D Loss:15.4739 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [41] G Loss:0.0000 D Loss:15.6419 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [42] G Loss:0.0000 D Loss:15.4556 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [43] G Loss:0.0000 D Loss:15.7051 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [44] G Loss:0.0000 D Loss:15.5385 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [45] G Loss:0.0000 D Loss:15.4213 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [46] G Loss:0.0000 D Loss:15.5555 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [47] G Loss:0.0000 D Loss:15.3259 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [48] G Loss:0.0000 D Loss:15.5358 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# Epoch [51] Step [49] G Loss:0.0000 D Loss:15.5108 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0003
# ...
# Epoch [98] Step [21] G Loss:0.0000 D Loss:15.4636 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [22] G Loss:0.0000 D Loss:15.4233 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [23] G Loss:0.0000 D Loss:15.3407 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [24] G Loss:0.0000 D Loss:15.2527 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [25] G Loss:0.0000 D Loss:15.3074 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [26] G Loss:0.0000 D Loss:15.4527 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [27] G Loss:0.0000 D Loss:15.5705 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [28] G Loss:0.0000 D Loss:15.2502 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [29] G Loss:0.0000 D Loss:15.3710 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [30] G Loss:0.0000 D Loss:15.5722 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [31] G Loss:0.0000 D Loss:15.3536 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [32] G Loss:0.0000 D Loss:15.1703 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [33] G Loss:0.0000 D Loss:15.3515 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [34] G Loss:0.0000 D Loss:15.3911 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [35] G Loss:0.0000 D Loss:15.4703 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [36] G Loss:0.0000 D Loss:15.3266 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [37] G Loss:0.0000 D Loss:15.5304 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [38] G Loss:0.0000 D Loss:15.4700 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [39] G Loss:0.0000 D Loss:15.3382 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [40] G Loss:0.0000 D Loss:15.2372 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [41] G Loss:0.0000 D Loss:15.4978 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [42] G Loss:0.0000 D Loss:15.6511 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [43] G Loss:0.0000 D Loss:15.5130 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [44] G Loss:0.0000 D Loss:15.4289 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [45] G Loss:0.0000 D Loss:14.9615 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [46] G Loss:0.0000 D Loss:15.3559 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [47] G Loss:0.0000 D Loss:15.4327 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [48] G Loss:0.0000 D Loss:15.3859 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [49] G Loss:0.0000 D Loss:15.5699 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [50] G Loss:0.0000 D Loss:15.5468 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [51] G Loss:0.0000 D Loss:15.7980 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [52] G Loss:0.0000 D Loss:15.6796 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [53] G Loss:0.0000 D Loss:15.6246 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [54] G Loss:0.0000 D Loss:15.0924 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [55] G Loss:0.0000 D Loss:15.4081 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [56] G Loss:0.0000 D Loss:15.1584 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [57] G Loss:0.0000 D Loss:15.2633 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [58] G Loss:0.0000 D Loss:15.2704 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [59] G Loss:0.0000 D Loss:14.9451 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [60] G Loss:0.0000 D Loss:14.9816 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [61] G Loss:0.0000 D Loss:15.6320 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [62] G Loss:0.0000 D Loss:15.3345 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [63] G Loss:0.0000 D Loss:15.5357 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [64] G Loss:0.0000 D Loss:15.3986 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [65] G Loss:0.0000 D Loss:15.6271 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [66] G Loss:0.0000 D Loss:15.5557 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [67] G Loss:0.0000 D Loss:15.4708 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [68] G Loss:0.0000 D Loss:15.5941 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [69] G Loss:0.0000 D Loss:14.9968 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [70] G Loss:0.0000 D Loss:15.5544 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [71] G Loss:0.0000 D Loss:15.3962 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [72] G Loss:0.0000 D Loss:15.4180 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [73] G Loss:0.0000 D Loss:15.3274 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [74] G Loss:0.0000 D Loss:15.5111 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [75] G Loss:0.0001 D Loss:15.3173 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0000
# Epoch [98] Step [76] G Loss:0.0000 D Loss:15.3759 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [77] G Loss:0.0000 D Loss:15.4712 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [78] G Loss:0.0000 D Loss:15.1644 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [79] G Loss:0.0000 D Loss:15.5127 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [80] G Loss:0.0000 D Loss:15.6389 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [81] G Loss:0.0000 D Loss:15.5668 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [82] G Loss:0.0000 D Loss:15.3946 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [83] G Loss:0.0000 D Loss:15.1121 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [84] G Loss:0.0000 D Loss:15.4736 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [85] G Loss:0.0000 D Loss:15.3355 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [86] G Loss:0.0000 D Loss:15.6156 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [87] G Loss:0.0000 D Loss:15.2558 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [88] G Loss:0.0000 D Loss:15.5353 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [89] G Loss:0.0000 D Loss:15.5258 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [90] G Loss:0.0000 D Loss:15.3771 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [91] G Loss:0.0000 D Loss:15.2605 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [98] Step [92] G Loss:0.0000 D Loss:15.4187 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [0] G Loss:0.0000 D Loss:15.3424 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [1] G Loss:0.0000 D Loss:15.4487 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [2] G Loss:0.0000 D Loss:15.3857 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [3] G Loss:0.0000 D Loss:15.4890 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [4] G Loss:0.0000 D Loss:15.4882 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [5] G Loss:0.0000 D Loss:15.4950 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [6] G Loss:0.0000 D Loss:15.5744 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [7] G Loss:0.0000 D Loss:15.2731 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [8] G Loss:0.0000 D Loss:15.4770 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [9] G Loss:0.0000 D Loss:15.0994 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [10] G Loss:0.0000 D Loss:15.5850 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [11] G Loss:0.0000 D Loss:15.4760 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [12] G Loss:0.0000 D Loss:15.2348 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [13] G Loss:0.0000 D Loss:15.3601 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [14] G Loss:0.0000 D Loss:15.4214 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [15] G Loss:0.0000 D Loss:14.8525 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [16] G Loss:0.0000 D Loss:15.3923 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [17] G Loss:0.0000 D Loss:15.2351 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [18] G Loss:0.0000 D Loss:15.5039 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [19] G Loss:0.0000 D Loss:15.6293 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [20] G Loss:0.0000 D Loss:15.2493 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [21] G Loss:0.0000 D Loss:15.3626 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [22] G Loss:0.0000 D Loss:15.3876 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [23] G Loss:0.0000 D Loss:15.6121 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [24] G Loss:0.0000 D Loss:15.7624 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [25] G Loss:0.0000 D Loss:15.4312 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [26] G Loss:0.0000 D Loss:15.5836 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [27] G Loss:0.0000 D Loss:15.3987 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [28] G Loss:0.0000 D Loss:15.5685 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [29] G Loss:0.0000 D Loss:15.6690 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [30] G Loss:0.0000 D Loss:15.5546 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [31] G Loss:0.0000 D Loss:15.2213 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [32] G Loss:0.0000 D Loss:15.6017 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [33] G Loss:0.0000 D Loss:15.1675 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [34] G Loss:0.0000 D Loss:15.5031 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [35] G Loss:0.0000 D Loss:15.2038 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [36] G Loss:0.0000 D Loss:15.6455 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [37] G Loss:0.0000 D Loss:15.2669 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [38] G Loss:0.0000 D Loss:15.4002 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [39] G Loss:0.0000 D Loss:15.4163 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [40] G Loss:0.0000 D Loss:15.4795 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [41] G Loss:0.0000 D Loss:15.4077 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [42] G Loss:0.0000 D Loss:15.3860 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [43] G Loss:0.0000 D Loss:15.2969 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [44] G Loss:0.0000 D Loss:15.4473 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [45] G Loss:0.0000 D Loss:15.2583 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [46] G Loss:0.0000 D Loss:15.4090 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [47] G Loss:0.0000 D Loss:15.2921 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [48] G Loss:0.0000 D Loss:15.0186 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [49] G Loss:0.0000 D Loss:15.6553 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [50] G Loss:0.0000 D Loss:15.4147 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [51] G Loss:0.0001 D Loss:15.2687 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0000
# Epoch [99] Step [52] G Loss:0.0000 D Loss:15.4501 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [53] G Loss:0.0000 D Loss:15.6157 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [54] G Loss:0.0000 D Loss:15.3740 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [55] G Loss:0.0000 D Loss:15.0118 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [56] G Loss:0.0000 D Loss:15.5515 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [57] G Loss:0.0001 D Loss:15.3195 Real Ave.: 1.0000 Fake Ave.: 0.9999 lr: 0.0000
# Epoch [99] Step [58] G Loss:0.0000 D Loss:15.3113 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [59] G Loss:0.0000 D Loss:15.1741 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [60] G Loss:0.0000 D Loss:15.6978 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [61] G Loss:0.0000 D Loss:15.5924 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [62] G Loss:0.0000 D Loss:15.4071 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [63] G Loss:0.0000 D Loss:15.5199 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [64] G Loss:0.0000 D Loss:15.4875 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [65] G Loss:0.0000 D Loss:15.3256 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [66] G Loss:0.0000 D Loss:15.0731 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [67] G Loss:0.0000 D Loss:15.4077 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [68] G Loss:0.0000 D Loss:15.1917 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [69] G Loss:0.0000 D Loss:15.4524 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [70] G Loss:0.0000 D Loss:15.6363 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [71] G Loss:0.0000 D Loss:15.2802 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [72] G Loss:0.0000 D Loss:15.2562 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [73] G Loss:0.0000 D Loss:15.2270 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [74] G Loss:0.0000 D Loss:15.2752 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [75] G Loss:0.0000 D Loss:15.2771 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [76] G Loss:0.0000 D Loss:15.3525 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [77] G Loss:0.0000 D Loss:15.5174 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [78] G Loss:0.0000 D Loss:15.4204 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [79] G Loss:0.0000 D Loss:15.6491 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [80] G Loss:0.0000 D Loss:15.3591 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [81] G Loss:0.0000 D Loss:15.5610 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [82] G Loss:0.0000 D Loss:15.4796 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [83] G Loss:0.0000 D Loss:15.1756 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [84] G Loss:0.0000 D Loss:15.4154 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [85] G Loss:0.0000 D Loss:15.2688 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [86] G Loss:0.0000 D Loss:15.8602 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [87] G Loss:0.0000 D Loss:15.3095 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [88] G Loss:0.0000 D Loss:15.2726 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [89] G Loss:0.0000 D Loss:15.2224 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [90] G Loss:0.0000 D Loss:15.3730 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [91] G Loss:0.0000 D Loss:15.6426 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000
# Epoch [99] Step [92] G Loss:0.0000 D Loss:15.4646 Real Ave.: 1.0000 Fake Ave.: 1.0000 lr: 0.0000

# %%
trainrX, _, train_sizer = mnist_reader([1])

# %%
f = open('/content/drive/MyDrive/Colab Notebooks/mnist_gan/train-images.idx3-ubyte')
loaded=np.fromfile(file=f,dtype=np.uint8)
trainX = loaded[16:].reshape((60000, 28, 28, 1)).astype(np.float32)

# %%
f=trainrX[0:64]

# %%
f.shape
# Out:
# (64, 28, 28, 1)
